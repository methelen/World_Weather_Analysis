# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
#from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["main"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chicama
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | marrakesh
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | urengoy
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | leningradskiy
# Processing Record 9 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 11 of Set 1 | yenagoa
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | pisco
# Processing Record 17 of Set 1 | san andres
# Processing Record 18 of Set 1 | bambous virieux
# Processing Record 19 of Set 1 | biak
# Processing Record 20 of Set 1 | santa ana
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | makakilo city
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | kieta
# Processing Record 25 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | shigony
# Processing Record 29 of Set 1 | faya
# Processing Record 30 of Set 1 | hvammstangi
# City not found. Skipping...
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | russell
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | prince george
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | poum
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | tilichiki
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | souillac
# Processing Record 44 of Set 1 | byron bay
# Processing Record 45 of Set 1 | saint-philippe
# Processing Record 46 of Set 1 | narsaq
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | iisalmi
# Processing Record 1 of Set 2 | santa fe
# Processing Record 2 of Set 2 | predejane
# Processing Record 3 of Set 2 | ponta delgada
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | srednekolymsk
# Processing Record 7 of Set 2 | maniitsoq
# Processing Record 8 of Set 2 | acapulco
# Processing Record 9 of Set 2 | katherine
# Processing Record 10 of Set 2 | kawalu
# Processing Record 11 of Set 2 | santa luzia
# Processing Record 12 of Set 2 | hovd
# Processing Record 13 of Set 2 | tiksi
# Processing Record 14 of Set 2 | alofi
# Processing Record 15 of Set 2 | tezu
# Processing Record 16 of Set 2 | vila do maio
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | penzance
# Processing Record 22 of Set 2 | richards bay
# Processing Record 23 of Set 2 | new norfolk
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | fortuna
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | mangrol
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | tautira
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | saldanha
# Processing Record 33 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 2 | wonthaggi
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | jubayl
# City not found. Skipping...
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | parole
# Processing Record 40 of Set 2 | salalah
# Processing Record 41 of Set 2 | tabou
# Processing Record 42 of Set 2 | atambua
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | quatre cocos
# Processing Record 45 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 2 | sept-iles
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | hambantota
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | qaanaaq
# Processing Record 1 of Set 3 | chuy
# Processing Record 2 of Set 3 | hobart
# Processing Record 3 of Set 3 | kindu
# Processing Record 4 of Set 3 | la macarena
# Processing Record 5 of Set 3 | bandarbeyla
# Processing Record 6 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | nagorsk
# Processing Record 10 of Set 3 | santa isabel
# Processing Record 11 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 3 | guerrero negro
# Processing Record 13 of Set 3 | whitianga
# Processing Record 14 of Set 3 | cap malheureux
# Processing Record 15 of Set 3 | zhigansk
# Processing Record 16 of Set 3 | esperance
# Processing Record 17 of Set 3 | cabo san lucas
# Processing Record 18 of Set 3 | faanui
# Processing Record 19 of Set 3 | coari
# Processing Record 20 of Set 3 | nizhniy odes
# Processing Record 21 of Set 3 | atuona
# Processing Record 22 of Set 3 | matara
# Processing Record 23 of Set 3 | yabrud
# Processing Record 24 of Set 3 | codrington
# Processing Record 25 of Set 3 | chernyshevskiy
# Processing Record 26 of Set 3 | port lincoln
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | lavrentiya
# Processing Record 29 of Set 3 | manthani
# Processing Record 30 of Set 3 | bindi
# Processing Record 31 of Set 3 | sao jose da coroa grande
# Processing Record 32 of Set 3 | bluff
# Processing Record 33 of Set 3 | abha
# Processing Record 34 of Set 3 | mount isa
# Processing Record 35 of Set 3 | kattivakkam
# Processing Record 36 of Set 3 | arraial do cabo
# Processing Record 37 of Set 3 | sao joao da barra
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | dubbo
# Processing Record 40 of Set 3 | sabang
# Processing Record 41 of Set 3 | sistranda
# Processing Record 42 of Set 3 | sao miguel do araguaia
# Processing Record 43 of Set 3 | badian
# Processing Record 44 of Set 3 | choya
# Processing Record 45 of Set 3 | santa cruz de la palma
# Processing Record 46 of Set 3 | kavaratti
# Processing Record 47 of Set 3 | dong hoi
# Processing Record 48 of Set 3 | clyde river
# Processing Record 49 of Set 3 | pindiga
# Processing Record 50 of Set 3 | talnakh
# Processing Record 1 of Set 4 | ilave
# Processing Record 2 of Set 4 | kavieng
# Processing Record 3 of Set 4 | okha
# Processing Record 4 of Set 4 | luderitz
# Processing Record 5 of Set 4 | lorengau
# Processing Record 6 of Set 4 | puerto ayora
# Processing Record 7 of Set 4 | mahuva
# Processing Record 8 of Set 4 | beringovskiy
# Processing Record 9 of Set 4 | barlinek
# Processing Record 10 of Set 4 | vardo
# Processing Record 11 of Set 4 | ancud
# Processing Record 12 of Set 4 | bac lieu
# Processing Record 13 of Set 4 | east london
# Processing Record 14 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 15 of Set 4 | bintulu
# Processing Record 16 of Set 4 | aswan
# Processing Record 17 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 4 | ahuimanu
# Processing Record 19 of Set 4 | port macquarie
# Processing Record 20 of Set 4 | caravelas
# Processing Record 21 of Set 4 | ahipara
# Processing Record 22 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 23 of Set 4 | cabedelo
# Processing Record 24 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 4 | nuuk
# Processing Record 26 of Set 4 | victoria
# Processing Record 27 of Set 4 | sukhumi
# Processing Record 28 of Set 4 | provideniya
# Processing Record 29 of Set 4 | araouane
# Processing Record 30 of Set 4 | aberdeen
# Processing Record 31 of Set 4 | port elizabeth
# Processing Record 32 of Set 4 | polunochnoye
# Processing Record 33 of Set 4 | impfondo
# Processing Record 34 of Set 4 | mamlyutka
# Processing Record 35 of Set 4 | osterburg
# Processing Record 36 of Set 4 | carnarvon
# Processing Record 37 of Set 4 | maceio
# Processing Record 38 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 4 | haines junction
# Processing Record 40 of Set 4 | nome
# Processing Record 41 of Set 4 | banda aceh
# Processing Record 42 of Set 4 | vao
# Processing Record 43 of Set 4 | shache
# Processing Record 44 of Set 4 | estacion coahuila
# Processing Record 45 of Set 4 | iqaluit
# Processing Record 46 of Set 4 | kidal
# Processing Record 47 of Set 4 | rokytne
# Processing Record 48 of Set 4 | dehloran
# Processing Record 49 of Set 4 | noumea
# Processing Record 50 of Set 4 | dondo
# Processing Record 1 of Set 5 | coruripe
# Processing Record 2 of Set 5 | campbell river
# Processing Record 3 of Set 5 | kharan
# Processing Record 4 of Set 5 | gorontalo
# Processing Record 5 of Set 5 | la union
# Processing Record 6 of Set 5 | okhotsk
# Processing Record 7 of Set 5 | ocampo
# Processing Record 8 of Set 5 | lompoc
# Processing Record 9 of Set 5 | los llanos de aridane
# Processing Record 10 of Set 5 | terra santa
# Processing Record 11 of Set 5 | najran
# Processing Record 12 of Set 5 | itarema
# Processing Record 13 of Set 5 | pangnirtung
# Processing Record 14 of Set 5 | rocha
# Processing Record 15 of Set 5 | necochea
# Processing Record 16 of Set 5 | cervo
# Processing Record 17 of Set 5 | lagoa
# Processing Record 18 of Set 5 | tsogni
# Processing Record 19 of Set 5 | suntar
# Processing Record 20 of Set 5 | maragogi
# Processing Record 21 of Set 5 | sola
# Processing Record 22 of Set 5 | mitu
# Processing Record 23 of Set 5 | katobu
# Processing Record 24 of Set 5 | wilkie
# Processing Record 25 of Set 5 | pavino
# Processing Record 26 of Set 5 | barcelos
# Processing Record 27 of Set 5 | college
# Processing Record 28 of Set 5 | at-bashi
# Processing Record 29 of Set 5 | senanga
# Processing Record 30 of Set 5 | severo-kurilsk
# Processing Record 31 of Set 5 | mweka
# Processing Record 32 of Set 5 | kruisfontein
# Processing Record 33 of Set 5 | cidreira
# Processing Record 34 of Set 5 | thinadhoo
# Processing Record 35 of Set 5 | margate
# Processing Record 36 of Set 5 | fomboni
# Processing Record 37 of Set 5 | hoi an
# Processing Record 38 of Set 5 | norman wells
# Processing Record 39 of Set 5 | varhaug
# Processing Record 40 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 5 | vrnjacka banja
# Processing Record 42 of Set 5 | grand gaube
# Processing Record 43 of Set 5 | fort wellington
# Processing Record 44 of Set 5 | touros
# Processing Record 45 of Set 5 | liku
# Processing Record 46 of Set 5 | broome
# Processing Record 47 of Set 5 | pyay
# Processing Record 48 of Set 5 | vanavara
# Processing Record 49 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 5 | poronaysk
# Processing Record 1 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 6 | ekibastuz
# Processing Record 3 of Set 6 | brejo da madre de deus
# Processing Record 4 of Set 6 | rio gallegos
# Processing Record 5 of Set 6 | camana
# Processing Record 6 of Set 6 | klaksvik
# Processing Record 7 of Set 6 | castle rock
# Processing Record 8 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 9 of Set 6 | yumen
# Processing Record 10 of Set 6 | mount gambier
# Processing Record 11 of Set 6 | kedainiai
# Processing Record 12 of Set 6 | ribeira grande
# Processing Record 13 of Set 6 | haapiti
# Processing Record 14 of Set 6 | lerwick
# Processing Record 15 of Set 6 | nova olimpia
# Processing Record 16 of Set 6 | bilibino
# Processing Record 17 of Set 6 | sao filipe
# Processing Record 18 of Set 6 | igarka
# Processing Record 19 of Set 6 | talara
# Processing Record 20 of Set 6 | broken hill
# Processing Record 21 of Set 6 | san quintin
# Processing Record 22 of Set 6 | kahului
# Processing Record 23 of Set 6 | gurupa
# Processing Record 24 of Set 6 | menongue
# Processing Record 25 of Set 6 | gafanha da encarnacao
# Processing Record 26 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 27 of Set 6 | sangar
# Processing Record 28 of Set 6 | fort nelson
# Processing Record 29 of Set 6 | saravan
# Processing Record 30 of Set 6 | redmond
# Processing Record 31 of Set 6 | ciudad del maiz
# Processing Record 32 of Set 6 | jining
# Processing Record 33 of Set 6 | yulara
# Processing Record 34 of Set 6 | vila velha
# Processing Record 35 of Set 6 | montmagny
# Processing Record 36 of Set 6 | nidzica
# Processing Record 37 of Set 6 | adrar
# Processing Record 38 of Set 6 | nemuro
# Processing Record 39 of Set 6 | damietta
# Processing Record 40 of Set 6 | sioux lookout
# Processing Record 41 of Set 6 | sorong
# Processing Record 42 of Set 6 | gushi
# Processing Record 43 of Set 6 | cap-aux-meules
# Processing Record 44 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 6 | krasnoselkup
# Processing Record 46 of Set 6 | korla
# Processing Record 47 of Set 6 | hun
# Processing Record 48 of Set 6 | tripoli
# Processing Record 49 of Set 6 | borovoy
# Processing Record 50 of Set 6 | ladwa
# Processing Record 1 of Set 7 | hibbing
# Processing Record 2 of Set 7 | nanortalik
# Processing Record 3 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 4 of Set 7 | hartselle
# Processing Record 5 of Set 7 | thompson
# Processing Record 6 of Set 7 | arlit
# Processing Record 7 of Set 7 | rawson
# Processing Record 8 of Set 7 | brae
# Processing Record 9 of Set 7 | seymchan
# Processing Record 10 of Set 7 | lengshuitan
# Processing Record 11 of Set 7 | marzuq
# Processing Record 12 of Set 7 | susner
# Processing Record 13 of Set 7 | whitehorse
# Processing Record 14 of Set 7 | madisonville
# Processing Record 15 of Set 7 | severo-yeniseyskiy
# Processing Record 16 of Set 7 | ayan
# Processing Record 17 of Set 7 | aybak
# City not found. Skipping...
# Processing Record 18 of Set 7 | batobato
# Processing Record 19 of Set 7 | kendari
# Processing Record 20 of Set 7 | swan river
# Processing Record 21 of Set 7 | archidona
# Processing Record 22 of Set 7 | lysa hora
# Processing Record 23 of Set 7 | flin flon
# Processing Record 24 of Set 7 | alyangula
# Processing Record 25 of Set 7 | staryy nadym
# Processing Record 26 of Set 7 | cherskiy
# Processing Record 27 of Set 7 | calbuco
# Processing Record 28 of Set 7 | birin
# Processing Record 29 of Set 7 | teluknaga
# Processing Record 30 of Set 7 | beshpagir
# Processing Record 31 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 7 | lexington
# Processing Record 33 of Set 7 | surt
# Processing Record 34 of Set 7 | loa janan
# Processing Record 35 of Set 7 | constitucion
# Processing Record 36 of Set 7 | torbay
# Processing Record 37 of Set 7 | yuzhno-kurilsk
# Processing Record 38 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 39 of Set 7 | havelock
# Processing Record 40 of Set 7 | tokuyama
# Processing Record 41 of Set 7 | hofn
# Processing Record 42 of Set 7 | catamarca
# Processing Record 43 of Set 7 | gamba
# Processing Record 44 of Set 7 | viedma
# Processing Record 45 of Set 7 | ratnagiri
# Processing Record 46 of Set 7 | shieli
# Processing Record 47 of Set 7 | starup
# Processing Record 48 of Set 7 | sibolga
# Processing Record 49 of Set 7 | longonjo
# Processing Record 50 of Set 7 | port hardy
# Processing Record 1 of Set 8 | jaque
# Processing Record 2 of Set 8 | pevek
# Processing Record 3 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 8 | pemangkat
# Processing Record 5 of Set 8 | olinda
# Processing Record 6 of Set 8 | tongchuan
# Processing Record 7 of Set 8 | cabo rojo
# Processing Record 8 of Set 8 | mosquera
# Processing Record 9 of Set 8 | tuatapere
# Processing Record 10 of Set 8 | ambanja
# Processing Record 11 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 12 of Set 8 | choszczno
# Processing Record 13 of Set 8 | coahuayana
# Processing Record 14 of Set 8 | jackson
# Processing Record 15 of Set 8 | zlatoustovsk
# City not found. Skipping...
# Processing Record 16 of Set 8 | valparaiso
# Processing Record 17 of Set 8 | chervona sloboda
# Processing Record 18 of Set 8 | luan
# Processing Record 19 of Set 8 | bonthe
# Processing Record 20 of Set 8 | high level
# Processing Record 21 of Set 8 | pacific grove
# Processing Record 22 of Set 8 | meulaboh
# Processing Record 23 of Set 8 | san patricio
# Processing Record 24 of Set 8 | santa cruz
# Processing Record 25 of Set 8 | sohbatpur
# Processing Record 26 of Set 8 | balkanabat
# Processing Record 27 of Set 8 | avera
# Processing Record 28 of Set 8 | sainte-suzanne
# Processing Record 29 of Set 8 | pathanamthitta
# Processing Record 30 of Set 8 | chai nat
# Processing Record 31 of Set 8 | tostamaa
# City not found. Skipping...
# Processing Record 32 of Set 8 | gondanglegi
# Processing Record 33 of Set 8 | kontagora
# Processing Record 34 of Set 8 | kabalo
# Processing Record 35 of Set 8 | kutum
# Processing Record 36 of Set 8 | buraydah
# Processing Record 37 of Set 8 | pasighat
# Processing Record 38 of Set 8 | yining
# Processing Record 39 of Set 8 | shingu
# Processing Record 40 of Set 8 | baragua
# Processing Record 41 of Set 8 | honiara
# Processing Record 42 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 8 | nambucca heads
# Processing Record 44 of Set 8 | caimito
# Processing Record 45 of Set 8 | miranorte
# City not found. Skipping...
# Processing Record 46 of Set 8 | carora
# Processing Record 47 of Set 8 | havoysund
# Processing Record 48 of Set 8 | coihaique
# Processing Record 49 of Set 8 | marihatag
# Processing Record 50 of Set 8 | vestmannaeyjar
# Processing Record 1 of Set 9 | bonavista
# Processing Record 2 of Set 9 | coquimbo
# Processing Record 3 of Set 9 | teguldet
# Processing Record 4 of Set 9 | tabuk
# Processing Record 5 of Set 9 | conde
# Processing Record 6 of Set 9 | imbituba
# Processing Record 7 of Set 9 | gogrial
# Processing Record 8 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 9 of Set 9 | sinnamary
# Processing Record 10 of Set 9 | san ignacio
# Processing Record 11 of Set 9 | ewa beach
# Processing Record 12 of Set 9 | gat
# Processing Record 13 of Set 9 | eugene
# Processing Record 14 of Set 9 | shatki
# Processing Record 15 of Set 9 | merauke
# Processing Record 16 of Set 9 | awjilah
# Processing Record 17 of Set 9 | saint-augustin
# Processing Record 18 of Set 9 | aykhal
# Processing Record 19 of Set 9 | juba
# Processing Record 20 of Set 9 | duldurga
# Processing Record 21 of Set 9 | cockburn town
# Processing Record 22 of Set 9 | metro
# Processing Record 23 of Set 9 | wilmington
# Processing Record 24 of Set 9 | burica
# City not found. Skipping...
# Processing Record 25 of Set 9 | varkkallai
# Processing Record 26 of Set 9 | nosy varika
# Processing Record 27 of Set 9 | todos santos
# Processing Record 28 of Set 9 | airai
# Processing Record 29 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 9 | kurchum
# Processing Record 31 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 32 of Set 9 | axim
# Processing Record 33 of Set 9 | port hedland
# Processing Record 34 of Set 9 | urumqi
# Processing Record 35 of Set 9 | bubaque
# Processing Record 36 of Set 9 | yar-sale
# Processing Record 37 of Set 9 | tazovskiy
# Processing Record 38 of Set 9 | garm
# City not found. Skipping...
# Processing Record 39 of Set 9 | zempoala
# Processing Record 40 of Set 9 | bikin
# Processing Record 41 of Set 9 | luanda
# Processing Record 42 of Set 9 | gigmoto
# Processing Record 43 of Set 9 | wonopringgo
# Processing Record 44 of Set 9 | kloulklubed
# Processing Record 45 of Set 9 | san joaquin
# Processing Record 46 of Set 9 | tenenkou
# Processing Record 47 of Set 9 | nador
# Processing Record 48 of Set 9 | taltal
# Processing Record 49 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 50 of Set 9 | belmonte
# Processing Record 1 of Set 10 | hasaki
# Processing Record 2 of Set 10 | pilar
# Processing Record 3 of Set 10 | ostrovnoy
# Processing Record 4 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 10 | utkivka
# Processing Record 6 of Set 10 | yerbogachen
# Processing Record 7 of Set 10 | atherton
# Processing Record 8 of Set 10 | chifeng
# Processing Record 9 of Set 10 | sao miguel do tapuio
# Processing Record 10 of Set 10 | luwingu
# Processing Record 11 of Set 10 | praia
# Processing Record 12 of Set 10 | abonnema
# Processing Record 13 of Set 10 | kokstad
# Processing Record 14 of Set 10 | elizabeth city
# Processing Record 15 of Set 10 | dingle
# Processing Record 16 of Set 10 | timmins
# Processing Record 17 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 10 | tual
# Processing Record 19 of Set 10 | nakhon phanom
# Processing Record 20 of Set 10 | jacareacanga
# Processing Record 21 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 22 of Set 10 | hamilton
# Processing Record 23 of Set 10 | namatanai
# Processing Record 24 of Set 10 | dudinka
# Processing Record 25 of Set 10 | kupang
# Processing Record 26 of Set 10 | ola
# Processing Record 27 of Set 10 | uulu
# Processing Record 28 of Set 10 | ninh binh
# Processing Record 29 of Set 10 | umea
# Processing Record 30 of Set 10 | tamandare
# Processing Record 31 of Set 10 | zaraza
# Processing Record 32 of Set 10 | chute-aux-outardes
# Processing Record 33 of Set 10 | ixtapa
# Processing Record 34 of Set 10 | tobermory
# Processing Record 35 of Set 10 | vostok
# Processing Record 36 of Set 10 | hecun
# Processing Record 37 of Set 10 | tynda
# Processing Record 38 of Set 10 | boa vista
# Processing Record 39 of Set 10 | le mars
# Processing Record 40 of Set 10 | beaumont
# Processing Record 41 of Set 10 | morgantown
# Processing Record 42 of Set 10 | terney
# Processing Record 43 of Set 10 | tucupita
# Processing Record 44 of Set 10 | jieshi
# Processing Record 45 of Set 10 | tessalit
# Processing Record 46 of Set 10 | sabha
# Processing Record 47 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 10 | ulladulla
# Processing Record 50 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 11 | koslan
# Processing Record 2 of Set 11 | inhambane
# Processing Record 3 of Set 11 | lensk
# Processing Record 4 of Set 11 | port moresby
# Processing Record 5 of Set 11 | lata
# Processing Record 6 of Set 11 | cazaje
# City not found. Skipping...
# Processing Record 7 of Set 11 | husavik
# Processing Record 8 of Set 11 | nizhniy kuranakh
# Processing Record 9 of Set 11 | eirunepe
# Processing Record 10 of Set 11 | tahoua
# Processing Record 11 of Set 11 | kalabo
# Processing Record 12 of Set 11 | vangaindrano
# Processing Record 13 of Set 11 | tura
# Processing Record 14 of Set 11 | la seyne-sur-mer
# Processing Record 15 of Set 11 | isangel
# Processing Record 16 of Set 11 | calama
# Processing Record 17 of Set 11 | sindor
# Processing Record 18 of Set 11 | vallenar
# Processing Record 19 of Set 11 | ust-nera
# Processing Record 20 of Set 11 | chichi
# Processing Record 21 of Set 11 | el chimbo
# Processing Record 22 of Set 11 | mitsamiouli
# Processing Record 23 of Set 11 | piacabucu
# Processing Record 24 of Set 11 | vrangel
# Processing Record 25 of Set 11 | riyadh
# Processing Record 26 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 27 of Set 11 | borba
# Processing Record 28 of Set 11 | tacana
# Processing Record 29 of Set 11 | bardiyah
# Processing Record 30 of Set 11 | bilma
# Processing Record 31 of Set 11 | mareeba
# Processing Record 32 of Set 11 | ust-uda
# Processing Record 33 of Set 11 | mahbubabad
# Processing Record 34 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 11 | ravar
# Processing Record 36 of Set 11 | tabory
# Processing Record 37 of Set 11 | katsuura
# Processing Record 38 of Set 11 | aklavik
# Processing Record 39 of Set 11 | ossora
# Processing Record 40 of Set 11 | dunedin
# Processing Record 41 of Set 11 | talaya
# Processing Record 42 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 11 | eureka
# Processing Record 44 of Set 11 | morden
# Processing Record 45 of Set 11 | tiarei
# Processing Record 46 of Set 11 | san vicente
# Processing Record 47 of Set 11 | ilanskiy
# Processing Record 48 of Set 11 | mildura
# Processing Record 49 of Set 11 | turkistan
# Processing Record 50 of Set 11 | praia da vitoria
# Processing Record 1 of Set 12 | arawa
# Processing Record 2 of Set 12 | raudeberg
# Processing Record 3 of Set 12 | novooleksiyivka
# Processing Record 4 of Set 12 | zalantun
# Processing Record 5 of Set 12 | lubao
# Processing Record 6 of Set 12 | honningsvag
# Processing Record 7 of Set 12 | buluang
# Processing Record 8 of Set 12 | agoura hills
# Processing Record 9 of Set 12 | port-de-bouc
# Processing Record 10 of Set 12 | khudumelapye
# Processing Record 11 of Set 12 | belfast
# Processing Record 12 of Set 12 | hirara
# Processing Record 13 of Set 12 | sur
# Processing Record 14 of Set 12 | nova vicosa
# Processing Record 15 of Set 12 | hanstholm
# Processing Record 16 of Set 12 | toumodi
# Processing Record 17 of Set 12 | dzaoudzi
# Processing Record 18 of Set 12 | joshimath
# Processing Record 19 of Set 12 | zhezkazgan
# Processing Record 20 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 12 | deputatskiy
# Processing Record 22 of Set 12 | el limon
# Processing Record 23 of Set 12 | preobrazheniye
# Processing Record 24 of Set 12 | camacha
# Processing Record 25 of Set 12 | vila franca do campo
# Processing Record 26 of Set 12 | pangody
# Processing Record 27 of Set 12 | christchurch
# Processing Record 28 of Set 12 | manaure
# Processing Record 29 of Set 12 | carballo
# Processing Record 30 of Set 12 | hualmay
# Processing Record 31 of Set 12 | saint-louis
# Processing Record 32 of Set 12 | oranjestad
# Processing Record 33 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 12 | hayden
# Processing Record 35 of Set 12 | langsa
# Processing Record 36 of Set 12 | colares
# Processing Record 37 of Set 12 | tambul
# City not found. Skipping...
# Processing Record 38 of Set 12 | kudahuvadhoo
# Processing Record 39 of Set 12 | kaka
# Processing Record 40 of Set 12 | neyshabur
# Processing Record 41 of Set 12 | matamoros
# Processing Record 42 of Set 12 | plaster rock
# Processing Record 43 of Set 12 | bure
# Processing Record 44 of Set 12 | kamenskiy
# Processing Record 45 of Set 12 | angra
# City not found. Skipping...
# Processing Record 46 of Set 12 | mo i rana
# Processing Record 47 of Set 12 | svetlogorsk
# Processing Record 48 of Set 12 | san cristobal
# Processing Record 49 of Set 12 | tarabha
# Processing Record 50 of Set 12 | salym
# Processing Record 1 of Set 13 | peniche
# Processing Record 2 of Set 13 | sambava
# Processing Record 3 of Set 13 | soyo
# Processing Record 4 of Set 13 | martapura
# Processing Record 5 of Set 13 | craig
# Processing Record 6 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 13 | singarayakonda
# Processing Record 8 of Set 13 | fairbanks
# Processing Record 9 of Set 13 | keetmanshoop
# Processing Record 10 of Set 13 | sobreira
# Processing Record 11 of Set 13 | port blair
# Processing Record 12 of Set 13 | manoel urbano
# Processing Record 13 of Set 13 | qaqortoq
# Processing Record 14 of Set 13 | xingyi
# Processing Record 15 of Set 13 | alugan
# Processing Record 16 of Set 13 | ballina
# Processing Record 17 of Set 13 | te anau
# Processing Record 18 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 13 | san-pedro
# Processing Record 20 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 13 | alta floresta
# Processing Record 22 of Set 13 | camocim
# Processing Record 23 of Set 13 | karratha
# Processing Record 24 of Set 13 | strezhevoy
# Processing Record 25 of Set 13 | boende
# Processing Record 26 of Set 13 | salinopolis
# Processing Record 27 of Set 13 | rovaniemi
# Processing Record 28 of Set 13 | tatawin
# Processing Record 29 of Set 13 | wajid
# Processing Record 30 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 31 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 32 of Set 13 | chapais
# Processing Record 33 of Set 13 | dawei
# Processing Record 34 of Set 13 | chengde
# Processing Record 35 of Set 13 | tres lagoas
# Processing Record 36 of Set 13 | tigil
# Processing Record 37 of Set 13 | east palo alto
# Processing Record 38 of Set 13 | pahrump
# Processing Record 39 of Set 13 | consett
# Processing Record 40 of Set 13 | gemena
# Processing Record 41 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 13 | baykit
# Processing Record 43 of Set 13 | belogorsk
# Processing Record 44 of Set 13 | maningrida
# Processing Record 45 of Set 13 | road town
# Processing Record 46 of Set 13 | wad madani
# Processing Record 47 of Set 13 | balkhash
# Processing Record 48 of Set 13 | wufeng
# Processing Record 49 of Set 13 | owando
# Processing Record 50 of Set 13 | kimbe
# Processing Record 1 of Set 14 | biloela
# Processing Record 2 of Set 14 | kalaleh
# Processing Record 3 of Set 14 | naze
# Processing Record 4 of Set 14 | santa maria
# Processing Record 5 of Set 14 | komsomolskiy
# Processing Record 6 of Set 14 | beloha
# Processing Record 7 of Set 14 | saraland
# Processing Record 8 of Set 14 | juneau
# Processing Record 9 of Set 14 | cuamba
# Processing Record 10 of Set 14 | north bend
# Processing Record 11 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 14 | port-gentil
# Processing Record 13 of Set 14 | chapayevka
# Processing Record 14 of Set 14 | matagami
# Processing Record 15 of Set 14 | wajima
# Processing Record 16 of Set 14 | luganville
# Processing Record 17 of Set 14 | naron
# Processing Record 18 of Set 14 | sechura
# Processing Record 19 of Set 14 | athabasca
# Processing Record 20 of Set 14 | hvolsvollur
# Processing Record 21 of Set 14 | grindavik
# Processing Record 22 of Set 14 | kuytun
# Processing Record 23 of Set 14 | portland
# Processing Record 24 of Set 14 | emerald
# Processing Record 25 of Set 14 | shubarkuduk
# Processing Record 26 of Set 14 | mahibadhoo
# Processing Record 27 of Set 14 | seddon
# Processing Record 28 of Set 14 | mkushi
# Processing Record 29 of Set 14 | tshela
# Processing Record 30 of Set 14 | vanimo
# Processing Record 31 of Set 14 | mayo
# Processing Record 32 of Set 14 | samarai
# Processing Record 33 of Set 14 | tyulgan
# Processing Record 34 of Set 14 | plettenberg bay
# Processing Record 35 of Set 14 | shar
# Processing Record 36 of Set 14 | griffith
# Processing Record 37 of Set 14 | goroka
# Processing Record 38 of Set 14 | aginskoye
# Processing Record 39 of Set 14 | tomatlan
# Processing Record 40 of Set 14 | hervey bay
# Processing Record 41 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 14 | turia
# Processing Record 43 of Set 14 | kashan
# Processing Record 44 of Set 14 | shintomi
# Processing Record 45 of Set 14 | teya
# Processing Record 46 of Set 14 | porto novo
# Processing Record 47 of Set 14 | manadhoo
# Processing Record 48 of Set 14 | hohhot
# Processing Record 49 of Set 14 | brokopondo
# Processing Record 50 of Set 14 | itarantim
# Processing Record 1 of Set 15 | doha
# Processing Record 2 of Set 15 | oranjemund
# Processing Record 3 of Set 15 | malaryta
# Processing Record 4 of Set 15 | oriximina
# Processing Record 5 of Set 15 | aboso
# Processing Record 6 of Set 15 | guapiacu
# Processing Record 7 of Set 15 | pochutla
# Processing Record 8 of Set 15 | netarhat
# Processing Record 9 of Set 15 | omboue
# Processing Record 10 of Set 15 | kargasok
# Processing Record 11 of Set 15 | san carlos
# Processing Record 12 of Set 15 | hoquiam
# Processing Record 13 of Set 15 | sasykoli
# Processing Record 14 of Set 15 | lasa
# Processing Record 15 of Set 15 | sarvar
# Processing Record 16 of Set 15 | nanpiao
# Processing Record 17 of Set 15 | burnie
# Processing Record 18 of Set 15 | tsiroanomandidy
# Processing Record 19 of Set 15 | monterey
# Processing Record 20 of Set 15 | mayumba
# Processing Record 21 of Set 15 | comodoro rivadavia
# Processing Record 22 of Set 15 | saint-felicien
# Processing Record 23 of Set 15 | lisakovsk
# Processing Record 24 of Set 15 | mazatlan
# Processing Record 25 of Set 15 | tyret pervaya
# Processing Record 26 of Set 15 | sidi ali
# Processing Record 27 of Set 15 | antalaha
# Processing Record 28 of Set 15 | otavi
# Processing Record 29 of Set 15 | bengkulu
# Processing Record 30 of Set 15 | wattegama
# Processing Record 31 of Set 15 | borger
# Processing Record 32 of Set 15 | bowen
# Processing Record 33 of Set 15 | sokolo
# Processing Record 34 of Set 15 | hay river
# Processing Record 35 of Set 15 | cloquet
# Processing Record 36 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 15 | winnemucca
# Processing Record 38 of Set 15 | khandyga
# Processing Record 39 of Set 15 | madang
# Processing Record 40 of Set 15 | tarsus
# Processing Record 41 of Set 15 | maltahohe
# Processing Record 42 of Set 15 | kondinskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Chicama      PE  -7.8447  -79.1469     59.54        65          76
# 1     Bredasdorp      ZA -34.5322   20.0403     74.28        60          28
# 2      Marrakesh      MA  31.6315   -8.0083     84.27        24           0
# 3      Busselton      AU -33.6500  115.3333     50.04        90          57
# 4        Urengoy      RU  65.9667   78.3667     13.89        95          99
# ..           ...     ...      ...       ...       ...       ...         ...
# 675     Khandyga      RU  62.6667  135.6000     -2.49       100         100
# 676       Madang      PG  -5.2246  145.7966     78.98        88          99
# 677       Tarsus      TR  36.9188   34.8784     75.58        50          84
# 678    Maltahohe      NA -24.8333   16.9833     87.96         4           0
# 679  Kondinskoye      RU  59.6481   67.4100     25.05        96         100
#
#      Wind Speed Current Description
# 0          6.31              Clouds
# 1          9.22              Clouds
# 2          6.91               Clear
# 3          7.76              Clouds
# 4         10.78              Clouds
# ..          ...                 ...
# 675        0.69              Clouds
# 676        6.55              Clouds
# 677        3.31              Clouds
# 678       20.38               Clear
# 679        6.08                Snow
#
# [680 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
